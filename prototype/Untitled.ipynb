# %%
test = "hallo#jj"
test.split("#")[0]
# Out:
# 'hallo'

# %%
test = "aku semalam makan roti dan daging ya".split()
chunk_size = 4
overlap = 2
all_ = []

# %%
for ix in range(0,len(test),chunk_size - overlap):
    all_.append(test[ix:ix+chunk_size])

# %%
all_
# Out:
# [['aku', 'semalam', 'makan', 'roti'],
#  ['makan', 'roti', 'dan', 'daging'],
#  ['dan', 'daging', 'ya'],
#  ['ya']]
